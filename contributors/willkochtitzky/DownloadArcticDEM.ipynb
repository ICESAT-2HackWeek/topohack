# %%
import sys
import os
import re
import getopt
import shutil
import posixpath
import lxml.etree
import calendar, time
import urllib.request as urllib2
import geopandas as gpd
import pandas as pd
from multiprocessing import Pool

# %%
bbox=[-160,60,-150,70]
dest_folder='/home/jovyan/topohack/data/ArcticDEM/ArcticDEM'
fetch_arcticDEM(bbox,dest_folder)
# Out:
# /home/jovyan/topohack/data/ArcticDEM
# --2019-06-21 00:34:00--  http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/indexes/ArcticDEM_Tile_Index_Rel7.zip
# Resolving data.pgc.umn.edu (data.pgc.umn.edu)... 134.84.212.106
# Connecting to data.pgc.umn.edu (data.pgc.umn.edu)|134.84.212.106|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 538740 (526K) [application/zip]
# Saving to: ‘ArcticDEM_Tile_Index_Rel7.zip’
#
# ArcticDEM_Tile_Inde 100%[===================>] 526.11K  2.64MB/s    in 0.2s
#
# 2019-06-21 00:34:00 (2.64 MB/s) - ‘ArcticDEM_Tile_Index_Rel7.zip’ saved [538740/538740]
#
# Archive:  ArcticDEM_Tile_Index_Rel7.zip
#   inflating: ArcticDEM_Tile_Index_Rel7.dbf
#   inflating: ArcticDEM_Tile_Index_Rel7.prj
#   inflating: ArcticDEM_Tile_Index_Rel7.shp
#   inflating: ArcticDEM_Tile_Index_Rel7.shx
# http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic/v3.0/2m/07_40/07_40_2_2_2m_v3.0.tar.gz -->
# 	/home/jovyan/topohack/data/ArcticDEM/ArcticDEM/07_40/07_40_2_2_2m_v3.0.tar.gz (new)
#
# http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic/v3.0/2m/07_41/07_41_1_1_2m_v3.0.tar.gz -->
# 	/home/jovyan/topohack/data/ArcticDEM/ArcticDEM/07_41/07_41_1_1_2m_v3.0.tar.gz (new)
#
# http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic/v3.0/2m/07_41/07_41_1_2_2m_v3.0.tar.gz -->
# 	/home/jovyan/topohack/data/ArcticDEM/ArcticDEM/07_41/07_41_1_2_2m_v3.0.tar.gz (new)
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-28:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/srv/conda/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-24:
# Traceback (most recent call last):
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-239-993ebf684128>", line 18, in arcticDEM_download
#     LIST=LIST, LOG=LOG, CLOBBER=CLOBBER, MODE=MODE)
#   File "<ipython-input-224-298cf8a23833>", line 66, in pgc_arcticdem_sync
#     CLOBBER, MODE)
#   File "<ipython-input-224-298cf8a23833>", line 130, in http_pull_file
#     shutil.copyfileobj(response, f, CHUNK)
#   File "/srv/conda/lib/python3.6/shutil.py", line 79, in copyfileobj
#     buf = fsrc.read(length)
#   File "/srv/conda/lib/python3.6/http/client.py", line 449, in read
#     n = self.readinto(b)
#   File "/srv/conda/lib/python3.6/http/client.py", line 493, in readinto
#     n = self.fp.readinto(b)
#   File "/srv/conda/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-248-0c10c255b37f> in fetch_arcticDEM(bbox, dest_folder)
#      28     with Pool(10) as p:
# ---> 29         p.map(arcticDEM_download,[tile_id for tile_id in input_var])
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     287         '''
# --> 288         return self._map_async(func, iterable, mapstar, chunksize).get()
#     289
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     663     def get(self, timeout=None):
# --> 664         self.wait(timeout)
#     665         if not self.ready():
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     660     def wait(self, timeout=None):
# --> 661         self._event.wait(timeout)
#     662
#
# /srv/conda/lib/python3.6/threading.py in wait(self, timeout)
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#
# /srv/conda/lib/python3.6/threading.py in wait(self, timeout)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-259-b3d51c7eea5d> in <module>
#       1 bbox=[-160,60,-150,70]
#       2 dest_folder='/home/jovyan/topohack/data/ArcticDEM/ArcticDEM'
# ----> 3 fetch_arcticDEM(bbox,dest_folder)
#
# <ipython-input-248-0c10c255b37f> in fetch_arcticDEM(bbox, dest_folder)
#      27
#      28     with Pool(10) as p:
# ---> 29         p.map(arcticDEM_download,[tile_id for tile_id in input_var])
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in __exit__(self, exc_type, exc_val, exc_tb)
#     635
#     636     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 637         self.terminate()
#     638
#     639 #
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in terminate(self)
#     565         self._state = TERMINATE
#     566         self._worker_handler._state = TERMINATE
# --> 567         self._terminate()
#     568
#     569     def join(self):
#
# /srv/conda/lib/python3.6/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     184                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     185                           self._callback, self._args, self._kwargs)
# --> 186                 res = self._callback(*self._args, **self._kwargs)
#     187             self._weakref = self._callback = self._args = \
#     188                             self._kwargs = self._key = None
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, worker_handler, task_handler, result_handler, cache)
#     595
#     596         util.debug('helping task handler/workers to finish')
# --> 597         cls._help_stuff_finish(inqueue, task_handler, len(pool))
#     598
#     599         assert result_handler.is_alive() or len(cache) == 0
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in _help_stuff_finish(inqueue, task_handler, size)
#     580         # task_handler may be blocked trying to put items on inqueue
#     581         util.debug('removing tasks from inqueue until task handler finished')
# --> 582         inqueue._rlock.acquire()
#     583         while task_handler.is_alive() and inqueue._reader.poll():
#     584             inqueue._reader.recv()
#
# KeyboardInterrupt:

# %%
def fetch_arcticDEM(bbox,dest_folder):
    
    #make a directory for ArcticDEM files
    # %mkdir ArcticDEM
    # %cd ArcticDEM/

    #download the Arctic DEM tiles from PGC
    # !wget -nc http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/indexes/ArcticDEM_Tile_Index_Rel7.zip
    # !unzip ArcticDEM_Tile_Index_Rel7.zip

    #define the bounding box that you want to download DEMs for
    bbox_w = bbox[0]
    bbox_s = bbox[1]
    bbox_e = bbox[2]
    bbox_n = bbox[3]
    
    #read in tiles from the ArcticDEM
    tiles = gpd.read_file("ArcticDEM_Tile_Index_Rel7.shp")
    tiles = tiles.to_crs({'init':'epsg:4326'}) #transform to WGS84

    #intersect the 
    intersection = tiles.cx[bbox_w:bbox_e,bbox_s:bbox_n]

    download_tiles_ids = intersection['tile'].values
    dest_folder = [dest_folder]*len(download_tiles_ids)
    input_var = list(zip(dest_folder,tile_id))
    
    with Pool(10) as p:
        p.map(arcticDEM_download,[tile_id for tile_id in input_var])

# %%
# Written by Tyler Sutterley (05/2019)

# adapted and put into Jupyter by M. Truffer (06/2019)
# adapted further by Will Kochtitzky and the #topohack team (06/2019)

#Program to sync ArcticDEM tar files
#http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic

#-- PURPOSE: check internet connection
def check_connection():
    #-- attempt to connect to public http Polar Geospatial Center host
    try:
        urllib2.urlopen('http://data.pgc.umn.edu/elev/dem/', timeout=1)
    except urllib2.URLError:
        raise RuntimeError('Check internet connection')
    else:
        return True

# %%
#-- PURPOSE: sync local ArcticDEM files with PGC public server
def pgc_arcticdem_sync(DIRECTORY, VERSION, RESOLUTION, TILES=None,
    LOG=False, LIST=False, CLOBBER=False, MODE=None):
    #-- recursively create data directory if not presently existing
    os.makedirs(DIRECTORY,MODE) if not os.path.exists(DIRECTORY) else None
    #-- create log file with list of synchronized files (or print to terminal)
    if LOG:
        #-- output to log file
        #-- format: PGC_ArcticDEM_sync_2002-04-01.log
        today = time.strftime('%Y-%m-%d',time.localtime())
        LOGFILE = 'PGC_ArcticDEM_sync_{0}.log'.format(today)
        fid = open(os.path.join(DIRECTORY,LOGFILE),'w')
        print('PGC ArcticDEM Sync Log ({0})'.format(today), file=fid)
        print('VERSION={0}'.format(VERSION), file=fid)
        print('RESOLUTION={0}'.format(RESOLUTION), file=fid)
        print('TILES={0}'.format(','.join(TILES)), file=fid) if TILES else None
    else:
        #-- standard output (terminal output)
        fid = sys.stdout

    #-- remote http server for PGC DEM data
    HOST = posixpath.join('http://data.pgc.umn.edu','elev','dem','setsm')
    #-- compile regular expression operators for tiles
    R1 = re.compile('|'.join(TILES)) if TILES else re.compile('\d+_\d+')
    R2 = re.compile('(\d+_\d+)_(.*?)\.tar\.gz')
    #-- compile regular expression operators for shapefiles
    R3 = re.compile('(.*?)_Tile_Index_Rel(\d+)\.zip')

    #-- compile HTML parser for lxml
    parser = lxml.etree.HTMLParser()

    #-- remote directory for data version and resolution
    remote_dir = posixpath.join(HOST,'ArcticDEM','mosaic',VERSION,RESOLUTION)
    #-- open connection with PGC server at remote directory
    request = urllib2.Request(remote_dir)
    response = urllib2.urlopen(request, timeout=20)
    #-- read and parse request for files (names and modified dates)
    tree = lxml.etree.parse(response, parser)
    colnames = tree.xpath('//td[@class="indexcolname"]//a/@href')
    collastmod = tree.xpath('//td[@class="indexcollastmod"]/text()')
    remote_sub = sorted([d for i,d in enumerate(colnames) if R1.match(d)])
    #-- for each tile subdirectory
    for sd in remote_sub:
        #-- check if data directory exists and recursively create if not
        local_dir = os.path.join(DIRECTORY,sd)
        if not os.access(local_dir, os.F_OK) and not LIST:
            os.makedirs(local_dir,MODE)
        #-- open connection with PGC server at remote directory
        request = urllib2.Request(posixpath.join(remote_dir,sd))
        response = urllib2.urlopen(request, timeout=20)
        #-- read and parse request for files (names and modified dates)
        tree = lxml.etree.parse(response, parser)
        colnames = tree.xpath('//td[@class="indexcolname"]//a/@href')
        collastmod = tree.xpath('//td[@class="indexcollastmod"]/text()')
        remote_file_lines = [i for i,f in enumerate(colnames) if R2.match(f)]
        #-- sync each ArcticDEM data file
        for i in remote_file_lines:
            #-- remote and local versions of the file
            remote_file = posixpath.join(remote_dir,sd,colnames[i])
            local_file = os.path.join(local_dir,colnames[i])
            #-- get last modified date and convert into unix time
            lastmodtime = time.strptime(collastmod[i].rstrip(),'%Y-%m-%d %H:%M')
            remote_mtime = calendar.timegm(lastmodtime)
            #-- sync ArcticDEM tar file
            http_pull_file(fid, remote_file, remote_mtime, local_file, LIST,
                CLOBBER, MODE)
        #-- close request
        request = None

    #-- remote directory for shapefiles of data version
    remote_dir = posixpath.join(HOST,'ArcticDEM','indexes')
    #-- open connection with PGC server at remote directory
    request = urllib2.Request(remote_dir)
    response = urllib2.urlopen(request, timeout=20)
    #-- read and parse request for files (names and modified dates)
    tree = lxml.etree.parse(response, parser)
    colnames = tree.xpath('//td[@class="indexcolname"]//a/@href')
    collastmod = tree.xpath('//td[@class="indexcollastmod"]/text()')
    remote_file_lines = [i for i,d in enumerate(colnames) if R3.match(d)]
    #-- sync each ArcticDEM shapefile
    for i in remote_file_lines:
        #-- remote and local versions of the file
        remote_file = posixpath.join(remote_dir,colnames[i])
        local_file = os.path.join(DIRECTORY,colnames[i])
        #-- get last modified date and convert into unix time
        lastmodtime = time.strptime(collastmod[i].rstrip(),'%Y-%m-%d %H:%M')
        remote_mtime = calendar.timegm(lastmodtime)
        #-- sync ArcticDEM shapefile
        http_pull_file(fid, remote_file, remote_mtime, local_file, LIST,
            CLOBBER, MODE)

    #-- close log file and set permissions level to MODE
    if LOG:
        fid.close()
        os.chmod(os.path.join(DIRECTORY,LOGFILE), MODE)

#-- PURPOSE: pull file from a remote host checking if file exists locally
#-- and if the remote file is newer than the local file
def http_pull_file(fid,remote_file,remote_mtime,local_file,LIST,CLOBBER,MODE):
    #-- if file exists in file system: check if remote file is newer
    TEST = False
    OVERWRITE = ' (clobber)'
    #-- check if local version of file exists
    if os.access(local_file, os.F_OK):
        #-- check last modification time of local file
        local_mtime = os.stat(local_file).st_mtime
        #-- if remote file is newer: overwrite the local file
        if (remote_mtime > local_mtime):
            TEST = True
            OVERWRITE = ' (overwrite)'
    else:
        TEST = True
        OVERWRITE = ' (new)'
    #-- if file does not exist locally, is to be overwritten, or CLOBBER is set
    if TEST or CLOBBER:
        #-- Printing files transferred
        print('{0} --> '.format(remote_file), file=fid)
        print('\t{0}{1}\n'.format(local_file,OVERWRITE), file=fid)
        #-- if executing copy command (not only printing the files)
        if not LIST:
            #-- Create and submit request. There are a wide range of exceptions
            #-- that can be thrown here, including HTTPError and URLError.
            request = urllib2.Request(remote_file)
            response = urllib2.urlopen(request, timeout=20)
            #-- chunked transfer encoding size
            CHUNK = 16 * 1024
            #-- copy contents to local file using chunked transfer encoding
            #-- transfer should work properly with ascii and binary data formats
            with open(local_file, 'wb') as f:
                shutil.copyfileobj(response, f, CHUNK)
            #-- keep remote modification time of file and local access time
            os.utime(local_file, (os.stat(local_file).st_atime, remote_mtime))
            os.chmod(local_file, MODE)

# %%
def arcticDEM_download (input_v):

    DIRECTORY = input_v[0]
    LIST = False
    LOG = False
    CLOBBER = False
    #-- ArcticDEM parameters
    VERSION = 'v3.0'
    RESOLUTION = '2m'
    # tile for Kaskawulsh
    TILES = input_v[1]
    #-- permissions mode of the local directories and files (number in octal)
    MODE = 0o775


    #-- check internet connection before attempting to run program
    pgc_arcticdem_sync(DIRECTORY, VERSION, RESOLUTION, TILES=TILES,
                   LIST=LIST, LOG=LOG, CLOBBER=CLOBBER, MODE=MODE)

# %%
# Out:
# http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic/v3.0/2m/42_08/42_08_1_1_2m_v3.0.tar.gz -->
# 	/home/jovyan/topohack/data/ArcticDEM/ArcticDEM/42_08/42_08_1_1_2m_v3.0.tar.gz (new)
#
# http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic/v3.0/2m/43_08/43_08_1_1_2m_v3.0.tar.gz -->
# 	/home/jovyan/topohack/data/ArcticDEM/ArcticDEM/43_08/43_08_1_1_2m_v3.0.tar.gz (new)
#
# http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic/v3.0/2m/43_09/43_09_2_2_2m_v3.0.tar.gz -->
# 	/home/jovyan/topohack/data/ArcticDEM/ArcticDEM/43_09/43_09_2_2_2m_v3.0.tar.gz (new)
#
# http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic/v3.0/2m/43_07/43_07_1_1_2m_v3.0.tar.gz -->
# 	/home/jovyan/topohack/data/ArcticDEM/ArcticDEM/43_07/43_07_1_1_2m_v3.0.tar.gz (new)
#
# http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic/v3.0/2m/42_07/42_07_1_1_2m_v3.0.tar.gz -->
# 	/home/jovyan/topohack/data/ArcticDEM/ArcticDEM/42_07/42_07_1_1_2m_v3.0.tar.gz (new)
#
# http://data.pgc.umn.edu/elev/dem/setsm/ArcticDEM/mosaic/v3.0/2m/43_08/43_08_1_2_2m_v3.0.tar.gz -->
# 	/home/jovyan/topohack/data/ArcticDEM/ArcticDEM/43_08/43_08_1_2_2m_v3.0.tar.gz (new)
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-10:
# Traceback (most recent call last):
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
# Process ForkPoolWorker-6:
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/srv/conda/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/srv/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/srv/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/srv/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/srv/conda/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/srv/conda/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/srv/conda/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-230-9ee696c1f3e8> in <module>
#       2
#       3 with Pool(10) as p:
# ----> 4     p.map(arcticDEM_download,[tile_id for tile_id in download_tiles_ids])
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     286         in a list that is returned.
#     287         '''
# --> 288         return self._map_async(func, iterable, mapstar, chunksize).get()
#     289
#     290     def starmap(self, func, iterable, chunksize=None):
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     662
#     663     def get(self, timeout=None):
# --> 664         self.wait(timeout)
#     665         if not self.ready():
#     666             raise TimeoutError
#
# /srv/conda/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     659
#     660     def wait(self, timeout=None):
# --> 661         self._event.wait(timeout)
#     662
#     663     def get(self, timeout=None):
#
# /srv/conda/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /srv/conda/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
